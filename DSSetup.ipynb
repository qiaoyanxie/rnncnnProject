# %% [markdown]
# # Setting Up Dataset

# %%
# !mkdir /root/.kaggle/
# !touch /root/.kaggle/kaggle.json
# !echo '{"username":"simarkareer","key":"ff816530aeb5eda4d7ce160a471cbe14"}' >> /root/.kaggle/kaggle.json
# !cat /root/.kaggle/kaggle.json
# !mkdir lyftdataset
# !cd lyftdataset
# !pip install --upgrade --force-reinstall --no-deps kaggle
# !kaggle --version
# !kaggle competitions download -c lyft-motion-prediction-autonomous-vehicles -p /content/lyftdataset/
cd lyftdataset/
# !unzip lyft-motion-prediction-autonomous-vehicles.zip

# %%
# !echo '{"username":"simarkareer","key":"ff816530aeb5eda4d7ce160a471cbe14"}' >> /root/.kaggle/kaggle.json

# %%
# !cat /root/.kaggle/kaggle.json
# Out:
# {"username":"simarkareer","key":"ff816530aeb5eda4d7ce160a471cbe14"}

# %%
# !mkdir lyftdataset
# !cd lyftdataset

# %%
# !pip install --upgrade --force-reinstall --no-deps kaggle
# !kaggle --version

# %%
# !kaggle competitions download -c lyft-motion-prediction-autonomous-vehicles -p /content/lyftdataset/
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading lyft-motion-prediction-autonomous-vehicles.zip to /content/lyftdataset
# 100% 18.2G/18.3G [02:33<00:00, 127MB/s]
# 100% 18.3G/18.3G [02:33<00:00, 128MB/s]

# %%
cd lyftdataset/
# Out:
# /content/lyftdataset

# %%
# !unzip lyft-motion-prediction-autonomous-vehicles.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: scenes/validate.zarr/agents_mask/0.5/8505.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8506.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8507.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8508.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8509.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/851.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8510.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8511.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8512.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8513.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8514.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8515.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8516.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8517.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8518.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8519.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/852.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8520.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8521.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8522.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8523.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8524.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8525.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8526.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8527.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8528.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8529.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/853.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8530.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8531.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8532.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8533.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8534.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8535.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8536.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8537.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8538.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8539.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/854.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8540.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8541.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8542.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8543.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8544.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8545.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8546.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8547.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8548.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8549.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/855.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8550.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8551.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8552.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8553.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8554.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8555.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8556.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8557.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8558.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8559.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/856.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8560.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8561.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8562.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8563.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8564.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8565.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8566.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8567.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8568.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8569.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/857.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8570.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8571.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8572.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8573.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8574.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8575.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8576.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8577.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8578.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8579.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/858.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8580.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8581.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8582.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8583.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8584.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8585.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8586.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8587.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8588.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8589.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/859.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8590.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8591.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8592.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8593.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8594.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8595.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8596.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8597.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8598.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8599.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/86.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/860.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8600.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8601.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8602.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8603.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8604.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8605.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8606.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8607.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8608.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8609.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/861.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8610.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8611.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8612.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8613.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8614.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8615.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8616.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8617.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8618.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8619.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/862.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8620.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8621.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8622.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8623.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8624.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8625.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8626.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8627.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8628.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8629.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/863.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8630.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8631.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8632.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8633.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8634.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8635.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8636.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8637.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8638.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8639.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/864.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8640.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8641.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8642.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8643.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8644.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8645.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8646.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8647.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8648.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8649.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/865.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8650.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8651.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8652.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8653.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8654.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8655.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8656.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8657.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8658.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8659.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/866.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8660.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8661.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8662.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8663.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8664.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8665.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8666.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8667.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8668.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8669.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/867.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8670.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8671.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8672.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8673.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8674.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8675.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8676.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8677.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8678.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8679.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/868.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8680.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8681.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8682.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8683.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8684.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8685.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8686.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8687.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8688.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8689.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/869.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8690.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8691.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8692.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8693.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8694.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8695.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8696.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8697.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8698.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8699.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/87.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/870.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8700.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8701.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8702.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8703.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8704.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8705.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8706.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8707.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8708.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8709.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/871.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8710.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8711.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8712.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8713.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8714.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8715.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8716.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8717.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8718.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8719.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/872.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8720.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8721.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8722.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8723.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8724.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8725.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8726.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8727.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8728.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8729.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/873.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8730.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8731.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8732.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8733.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8734.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8735.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8736.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8737.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8738.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8739.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/874.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8740.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8741.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8742.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8743.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8744.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8745.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8746.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8747.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8748.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8749.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/875.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8750.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8751.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8752.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8753.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8754.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8755.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8756.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8757.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8758.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8759.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/876.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8760.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8761.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8762.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8763.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8764.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8765.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8766.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8767.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8768.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8769.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/877.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8770.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8771.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8772.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8773.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8774.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8775.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8776.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8777.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8778.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8779.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/878.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8780.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8781.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8782.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8783.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8784.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8785.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8786.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8787.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8788.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8789.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/879.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8790.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8791.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8792.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8793.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8794.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8795.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8796.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8797.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8798.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8799.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/88.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/880.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8800.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8801.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8802.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8803.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8804.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8805.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8806.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8807.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8808.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8809.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/881.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8810.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8811.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8812.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8813.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8814.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8815.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8816.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8817.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8818.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8819.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/882.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8820.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8821.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8822.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8823.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8824.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8825.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8826.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8827.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8828.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8829.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/883.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8830.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8831.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8832.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8833.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8834.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8835.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8836.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8837.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8838.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8839.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/884.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8840.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8841.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8842.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8843.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8844.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8845.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8846.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8847.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8848.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8849.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/885.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8850.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8851.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8852.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8853.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8854.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8855.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8856.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8857.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8858.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8859.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/886.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8860.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8861.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8862.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8863.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8864.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8865.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8866.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8867.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8868.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8869.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/887.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8870.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8871.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8872.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8873.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8874.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8875.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8876.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8877.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8878.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8879.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/888.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8880.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8881.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8882.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8883.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8884.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8885.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8886.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8887.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8888.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8889.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/889.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8890.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8891.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8892.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8893.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8894.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8895.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8896.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8897.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8898.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8899.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/89.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/890.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8900.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8901.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8902.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8903.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8904.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8905.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8906.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8907.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8908.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8909.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/891.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8910.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8911.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8912.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8913.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8914.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8915.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8916.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8917.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8918.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8919.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/892.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8920.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8921.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8922.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8923.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8924.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8925.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8926.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8927.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8928.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8929.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/893.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8930.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8931.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8932.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8933.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8934.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8935.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8936.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8937.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8938.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8939.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/894.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8940.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8941.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8942.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8943.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8944.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8945.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8946.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8947.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8948.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8949.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/895.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8950.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8951.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8952.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8953.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8954.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8955.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8956.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8957.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8958.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8959.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/896.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8960.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8961.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8962.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8963.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8964.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8965.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8966.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8967.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8968.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8969.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/897.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8970.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8971.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8972.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8973.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8974.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8975.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8976.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8977.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8978.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8979.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/898.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8980.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8981.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8982.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8983.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8984.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8985.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8986.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8987.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8988.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8989.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/899.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8990.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8991.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8992.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8993.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8994.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8995.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8996.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8997.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8998.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/8999.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/90.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/900.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9000.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9001.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9002.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9003.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9004.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9005.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9006.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9007.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9008.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9009.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/901.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9010.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9011.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9012.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9013.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9014.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9015.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9016.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9017.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9018.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9019.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/902.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9020.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9021.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9022.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9023.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9024.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9025.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9026.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9027.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9028.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9029.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/903.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9030.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9031.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9032.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9033.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9034.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9035.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9036.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9037.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9038.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9039.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/904.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9040.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9041.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9042.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9043.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9044.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9045.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9046.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9047.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9048.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9049.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/905.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9050.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9051.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9052.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9053.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9054.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9055.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9056.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9057.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9058.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9059.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/906.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9060.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9061.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9062.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9063.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9064.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9065.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9066.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9067.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9068.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9069.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/907.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9070.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9071.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9072.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9073.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9074.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9075.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9076.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9077.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9078.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9079.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/908.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9080.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9081.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9082.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9083.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9084.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9085.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9086.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9087.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9088.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9089.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/909.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9090.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9091.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9092.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9093.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9094.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9095.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9096.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9097.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9098.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9099.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/91.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/910.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9100.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9101.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9102.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9103.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9104.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9105.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9106.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9107.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9108.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9109.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/911.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9110.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9111.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9112.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9113.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9114.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9115.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9116.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9117.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9118.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9119.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/912.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9120.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9121.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9122.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9123.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9124.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9125.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9126.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9127.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9128.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9129.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/913.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9130.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9131.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9132.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9133.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9134.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9135.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9136.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9137.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9138.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9139.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/914.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9140.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9141.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9142.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9143.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9144.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9145.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9146.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9147.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9148.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9149.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/915.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9150.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9151.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9152.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9153.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9154.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9155.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9156.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9157.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9158.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9159.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/916.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9160.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9161.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9162.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9163.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9164.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9165.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9166.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9167.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9168.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9169.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/917.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9170.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9171.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9172.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9173.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9174.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9175.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9176.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9177.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9178.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9179.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/918.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9180.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9181.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9182.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9183.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9184.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9185.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9186.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9187.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9188.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9189.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/919.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9190.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9191.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9192.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9193.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9194.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9195.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9196.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9197.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9198.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9199.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/92.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/920.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9200.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9201.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9202.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9203.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9204.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9205.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9206.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9207.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9208.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9209.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/921.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9210.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9211.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9212.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9213.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9214.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9215.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9216.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9217.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9218.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9219.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/922.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9220.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9221.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9222.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9223.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9224.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9225.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9226.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9227.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9228.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9229.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/923.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9230.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9231.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9232.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9233.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9234.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9235.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9236.0
#   inflating: scenes/validate.zarr/agents_mask/0.5/9237.0
# ...
#   inflating: scenes/validate.zarr/traffic_light_faces/761
#   inflating: scenes/validate.zarr/traffic_light_faces/762
#   inflating: scenes/validate.zarr/traffic_light_faces/763
#   inflating: scenes/validate.zarr/traffic_light_faces/764
#   inflating: scenes/validate.zarr/traffic_light_faces/765
#   inflating: scenes/validate.zarr/traffic_light_faces/766
#   inflating: scenes/validate.zarr/traffic_light_faces/767
#   inflating: scenes/validate.zarr/traffic_light_faces/768
#   inflating: scenes/validate.zarr/traffic_light_faces/769
#   inflating: scenes/validate.zarr/traffic_light_faces/77
#   inflating: scenes/validate.zarr/traffic_light_faces/770
#   inflating: scenes/validate.zarr/traffic_light_faces/771
#   inflating: scenes/validate.zarr/traffic_light_faces/772
#   inflating: scenes/validate.zarr/traffic_light_faces/773
#   inflating: scenes/validate.zarr/traffic_light_faces/774
#   inflating: scenes/validate.zarr/traffic_light_faces/775
#   inflating: scenes/validate.zarr/traffic_light_faces/776
#   inflating: scenes/validate.zarr/traffic_light_faces/777
#   inflating: scenes/validate.zarr/traffic_light_faces/778
#   inflating: scenes/validate.zarr/traffic_light_faces/779
#   inflating: scenes/validate.zarr/traffic_light_faces/78
#   inflating: scenes/validate.zarr/traffic_light_faces/780
#   inflating: scenes/validate.zarr/traffic_light_faces/781
#   inflating: scenes/validate.zarr/traffic_light_faces/782
#   inflating: scenes/validate.zarr/traffic_light_faces/783
#   inflating: scenes/validate.zarr/traffic_light_faces/784
#   inflating: scenes/validate.zarr/traffic_light_faces/785
#   inflating: scenes/validate.zarr/traffic_light_faces/786
#   inflating: scenes/validate.zarr/traffic_light_faces/787
#   inflating: scenes/validate.zarr/traffic_light_faces/788
#   inflating: scenes/validate.zarr/traffic_light_faces/789
#   inflating: scenes/validate.zarr/traffic_light_faces/79
#   inflating: scenes/validate.zarr/traffic_light_faces/790
#   inflating: scenes/validate.zarr/traffic_light_faces/791
#   inflating: scenes/validate.zarr/traffic_light_faces/792
#   inflating: scenes/validate.zarr/traffic_light_faces/793
#   inflating: scenes/validate.zarr/traffic_light_faces/794
#   inflating: scenes/validate.zarr/traffic_light_faces/795
#   inflating: scenes/validate.zarr/traffic_light_faces/796
#   inflating: scenes/validate.zarr/traffic_light_faces/797
#   inflating: scenes/validate.zarr/traffic_light_faces/798
#   inflating: scenes/validate.zarr/traffic_light_faces/799
#   inflating: scenes/validate.zarr/traffic_light_faces/8
#   inflating: scenes/validate.zarr/traffic_light_faces/80
#   inflating: scenes/validate.zarr/traffic_light_faces/800
#   inflating: scenes/validate.zarr/traffic_light_faces/801
#   inflating: scenes/validate.zarr/traffic_light_faces/802
#   inflating: scenes/validate.zarr/traffic_light_faces/803
#   inflating: scenes/validate.zarr/traffic_light_faces/804
#   inflating: scenes/validate.zarr/traffic_light_faces/805
#   inflating: scenes/validate.zarr/traffic_light_faces/806
#   inflating: scenes/validate.zarr/traffic_light_faces/807
#   inflating: scenes/validate.zarr/traffic_light_faces/808
#   inflating: scenes/validate.zarr/traffic_light_faces/809
#   inflating: scenes/validate.zarr/traffic_light_faces/81
#   inflating: scenes/validate.zarr/traffic_light_faces/810
#   inflating: scenes/validate.zarr/traffic_light_faces/811
#   inflating: scenes/validate.zarr/traffic_light_faces/812
#   inflating: scenes/validate.zarr/traffic_light_faces/813
#   inflating: scenes/validate.zarr/traffic_light_faces/814
#   inflating: scenes/validate.zarr/traffic_light_faces/815
#   inflating: scenes/validate.zarr/traffic_light_faces/816
#   inflating: scenes/validate.zarr/traffic_light_faces/817
#   inflating: scenes/validate.zarr/traffic_light_faces/818
#   inflating: scenes/validate.zarr/traffic_light_faces/819
#   inflating: scenes/validate.zarr/traffic_light_faces/82
#   inflating: scenes/validate.zarr/traffic_light_faces/820
#   inflating: scenes/validate.zarr/traffic_light_faces/821
#   inflating: scenes/validate.zarr/traffic_light_faces/822
#   inflating: scenes/validate.zarr/traffic_light_faces/823
#   inflating: scenes/validate.zarr/traffic_light_faces/824
#   inflating: scenes/validate.zarr/traffic_light_faces/825
#   inflating: scenes/validate.zarr/traffic_light_faces/826
#   inflating: scenes/validate.zarr/traffic_light_faces/827
#   inflating: scenes/validate.zarr/traffic_light_faces/828
#   inflating: scenes/validate.zarr/traffic_light_faces/829
#   inflating: scenes/validate.zarr/traffic_light_faces/83
#   inflating: scenes/validate.zarr/traffic_light_faces/830
#   inflating: scenes/validate.zarr/traffic_light_faces/831
#   inflating: scenes/validate.zarr/traffic_light_faces/832
#   inflating: scenes/validate.zarr/traffic_light_faces/833
#   inflating: scenes/validate.zarr/traffic_light_faces/834
#   inflating: scenes/validate.zarr/traffic_light_faces/835
#   inflating: scenes/validate.zarr/traffic_light_faces/836
#   inflating: scenes/validate.zarr/traffic_light_faces/837
#   inflating: scenes/validate.zarr/traffic_light_faces/838
#   inflating: scenes/validate.zarr/traffic_light_faces/839
#   inflating: scenes/validate.zarr/traffic_light_faces/84
#   inflating: scenes/validate.zarr/traffic_light_faces/840
#   inflating: scenes/validate.zarr/traffic_light_faces/841
#   inflating: scenes/validate.zarr/traffic_light_faces/842
#   inflating: scenes/validate.zarr/traffic_light_faces/843
#   inflating: scenes/validate.zarr/traffic_light_faces/844
#   inflating: scenes/validate.zarr/traffic_light_faces/845
#   inflating: scenes/validate.zarr/traffic_light_faces/846
#   inflating: scenes/validate.zarr/traffic_light_faces/847
#   inflating: scenes/validate.zarr/traffic_light_faces/848
#   inflating: scenes/validate.zarr/traffic_light_faces/849
#   inflating: scenes/validate.zarr/traffic_light_faces/85
#   inflating: scenes/validate.zarr/traffic_light_faces/850
#   inflating: scenes/validate.zarr/traffic_light_faces/851
#   inflating: scenes/validate.zarr/traffic_light_faces/852
#   inflating: scenes/validate.zarr/traffic_light_faces/853
#   inflating: scenes/validate.zarr/traffic_light_faces/854
#   inflating: scenes/validate.zarr/traffic_light_faces/855
#   inflating: scenes/validate.zarr/traffic_light_faces/856
#   inflating: scenes/validate.zarr/traffic_light_faces/857
#   inflating: scenes/validate.zarr/traffic_light_faces/858
#   inflating: scenes/validate.zarr/traffic_light_faces/859
#   inflating: scenes/validate.zarr/traffic_light_faces/86
#   inflating: scenes/validate.zarr/traffic_light_faces/860
#   inflating: scenes/validate.zarr/traffic_light_faces/861
#   inflating: scenes/validate.zarr/traffic_light_faces/862
#   inflating: scenes/validate.zarr/traffic_light_faces/863
#   inflating: scenes/validate.zarr/traffic_light_faces/864
#   inflating: scenes/validate.zarr/traffic_light_faces/865
#   inflating: scenes/validate.zarr/traffic_light_faces/866
#   inflating: scenes/validate.zarr/traffic_light_faces/867
#   inflating: scenes/validate.zarr/traffic_light_faces/868
#   inflating: scenes/validate.zarr/traffic_light_faces/869
#   inflating: scenes/validate.zarr/traffic_light_faces/87
#   inflating: scenes/validate.zarr/traffic_light_faces/870
#   inflating: scenes/validate.zarr/traffic_light_faces/871
#   inflating: scenes/validate.zarr/traffic_light_faces/872
#   inflating: scenes/validate.zarr/traffic_light_faces/873
#   inflating: scenes/validate.zarr/traffic_light_faces/874
#   inflating: scenes/validate.zarr/traffic_light_faces/875
#   inflating: scenes/validate.zarr/traffic_light_faces/876
#   inflating: scenes/validate.zarr/traffic_light_faces/877
#   inflating: scenes/validate.zarr/traffic_light_faces/878
#   inflating: scenes/validate.zarr/traffic_light_faces/879
#   inflating: scenes/validate.zarr/traffic_light_faces/88
#   inflating: scenes/validate.zarr/traffic_light_faces/880
#   inflating: scenes/validate.zarr/traffic_light_faces/881
#   inflating: scenes/validate.zarr/traffic_light_faces/882
#   inflating: scenes/validate.zarr/traffic_light_faces/883
#   inflating: scenes/validate.zarr/traffic_light_faces/884
#   inflating: scenes/validate.zarr/traffic_light_faces/885
#   inflating: scenes/validate.zarr/traffic_light_faces/886
#   inflating: scenes/validate.zarr/traffic_light_faces/887
#   inflating: scenes/validate.zarr/traffic_light_faces/888
#   inflating: scenes/validate.zarr/traffic_light_faces/889
#   inflating: scenes/validate.zarr/traffic_light_faces/89
#   inflating: scenes/validate.zarr/traffic_light_faces/890
#   inflating: scenes/validate.zarr/traffic_light_faces/891
#   inflating: scenes/validate.zarr/traffic_light_faces/892
#   inflating: scenes/validate.zarr/traffic_light_faces/893
#   inflating: scenes/validate.zarr/traffic_light_faces/894
#   inflating: scenes/validate.zarr/traffic_light_faces/895
#   inflating: scenes/validate.zarr/traffic_light_faces/896
#   inflating: scenes/validate.zarr/traffic_light_faces/897
#   inflating: scenes/validate.zarr/traffic_light_faces/898
#   inflating: scenes/validate.zarr/traffic_light_faces/899
#   inflating: scenes/validate.zarr/traffic_light_faces/9
#   inflating: scenes/validate.zarr/traffic_light_faces/90
#   inflating: scenes/validate.zarr/traffic_light_faces/900
#   inflating: scenes/validate.zarr/traffic_light_faces/901
#   inflating: scenes/validate.zarr/traffic_light_faces/902
#   inflating: scenes/validate.zarr/traffic_light_faces/903
#   inflating: scenes/validate.zarr/traffic_light_faces/904
#   inflating: scenes/validate.zarr/traffic_light_faces/905
#   inflating: scenes/validate.zarr/traffic_light_faces/906
#   inflating: scenes/validate.zarr/traffic_light_faces/907
#   inflating: scenes/validate.zarr/traffic_light_faces/908
#   inflating: scenes/validate.zarr/traffic_light_faces/909
#   inflating: scenes/validate.zarr/traffic_light_faces/91
#   inflating: scenes/validate.zarr/traffic_light_faces/910
#   inflating: scenes/validate.zarr/traffic_light_faces/911
#   inflating: scenes/validate.zarr/traffic_light_faces/912
#   inflating: scenes/validate.zarr/traffic_light_faces/913
#   inflating: scenes/validate.zarr/traffic_light_faces/914
#   inflating: scenes/validate.zarr/traffic_light_faces/915
#   inflating: scenes/validate.zarr/traffic_light_faces/916
#   inflating: scenes/validate.zarr/traffic_light_faces/917
#   inflating: scenes/validate.zarr/traffic_light_faces/918
#   inflating: scenes/validate.zarr/traffic_light_faces/919
#   inflating: scenes/validate.zarr/traffic_light_faces/92
#   inflating: scenes/validate.zarr/traffic_light_faces/920
#   inflating: scenes/validate.zarr/traffic_light_faces/921
#   inflating: scenes/validate.zarr/traffic_light_faces/922
#   inflating: scenes/validate.zarr/traffic_light_faces/923
#   inflating: scenes/validate.zarr/traffic_light_faces/924
#   inflating: scenes/validate.zarr/traffic_light_faces/925
#   inflating: scenes/validate.zarr/traffic_light_faces/926
#   inflating: scenes/validate.zarr/traffic_light_faces/927
#   inflating: scenes/validate.zarr/traffic_light_faces/928
#   inflating: scenes/validate.zarr/traffic_light_faces/929
#   inflating: scenes/validate.zarr/traffic_light_faces/93
#   inflating: scenes/validate.zarr/traffic_light_faces/930
#   inflating: scenes/validate.zarr/traffic_light_faces/931
#   inflating: scenes/validate.zarr/traffic_light_faces/932
#   inflating: scenes/validate.zarr/traffic_light_faces/933
#   inflating: scenes/validate.zarr/traffic_light_faces/934
#   inflating: scenes/validate.zarr/traffic_light_faces/935
#   inflating: scenes/validate.zarr/traffic_light_faces/936
#   inflating: scenes/validate.zarr/traffic_light_faces/937
#   inflating: scenes/validate.zarr/traffic_light_faces/938
#   inflating: scenes/validate.zarr/traffic_light_faces/939
#   inflating: scenes/validate.zarr/traffic_light_faces/94
#   inflating: scenes/validate.zarr/traffic_light_faces/940
#   inflating: scenes/validate.zarr/traffic_light_faces/941
#   inflating: scenes/validate.zarr/traffic_light_faces/942
#   inflating: scenes/validate.zarr/traffic_light_faces/943
#   inflating: scenes/validate.zarr/traffic_light_faces/944
#   inflating: scenes/validate.zarr/traffic_light_faces/945
#   inflating: scenes/validate.zarr/traffic_light_faces/946
#   inflating: scenes/validate.zarr/traffic_light_faces/947
#   inflating: scenes/validate.zarr/traffic_light_faces/948
#   inflating: scenes/validate.zarr/traffic_light_faces/949
#   inflating: scenes/validate.zarr/traffic_light_faces/95
#   inflating: scenes/validate.zarr/traffic_light_faces/950
#   inflating: scenes/validate.zarr/traffic_light_faces/951
#   inflating: scenes/validate.zarr/traffic_light_faces/952
#   inflating: scenes/validate.zarr/traffic_light_faces/953
#   inflating: scenes/validate.zarr/traffic_light_faces/954
#   inflating: scenes/validate.zarr/traffic_light_faces/955
#   inflating: scenes/validate.zarr/traffic_light_faces/956
#   inflating: scenes/validate.zarr/traffic_light_faces/957
#   inflating: scenes/validate.zarr/traffic_light_faces/958
#   inflating: scenes/validate.zarr/traffic_light_faces/959
#   inflating: scenes/validate.zarr/traffic_light_faces/96
#   inflating: scenes/validate.zarr/traffic_light_faces/960
#   inflating: scenes/validate.zarr/traffic_light_faces/961
#   inflating: scenes/validate.zarr/traffic_light_faces/962
#   inflating: scenes/validate.zarr/traffic_light_faces/963
#   inflating: scenes/validate.zarr/traffic_light_faces/964
#   inflating: scenes/validate.zarr/traffic_light_faces/965
#   inflating: scenes/validate.zarr/traffic_light_faces/966
#   inflating: scenes/validate.zarr/traffic_light_faces/967
#   inflating: scenes/validate.zarr/traffic_light_faces/968
#   inflating: scenes/validate.zarr/traffic_light_faces/969
#   inflating: scenes/validate.zarr/traffic_light_faces/97
#   inflating: scenes/validate.zarr/traffic_light_faces/970
#   inflating: scenes/validate.zarr/traffic_light_faces/971
#   inflating: scenes/validate.zarr/traffic_light_faces/972
#   inflating: scenes/validate.zarr/traffic_light_faces/973
#   inflating: scenes/validate.zarr/traffic_light_faces/974
#   inflating: scenes/validate.zarr/traffic_light_faces/975
#   inflating: scenes/validate.zarr/traffic_light_faces/976
#   inflating: scenes/validate.zarr/traffic_light_faces/977
#   inflating: scenes/validate.zarr/traffic_light_faces/978
#   inflating: scenes/validate.zarr/traffic_light_faces/979
#   inflating: scenes/validate.zarr/traffic_light_faces/98
#   inflating: scenes/validate.zarr/traffic_light_faces/980
#   inflating: scenes/validate.zarr/traffic_light_faces/981
#   inflating: scenes/validate.zarr/traffic_light_faces/982
#   inflating: scenes/validate.zarr/traffic_light_faces/983
#   inflating: scenes/validate.zarr/traffic_light_faces/984
#   inflating: scenes/validate.zarr/traffic_light_faces/985
#   inflating: scenes/validate.zarr/traffic_light_faces/986
#   inflating: scenes/validate.zarr/traffic_light_faces/987
#   inflating: scenes/validate.zarr/traffic_light_faces/988
#   inflating: scenes/validate.zarr/traffic_light_faces/989
#   inflating: scenes/validate.zarr/traffic_light_faces/99
#   inflating: scenes/validate.zarr/traffic_light_faces/990
#   inflating: scenes/validate.zarr/traffic_light_faces/991
#   inflating: scenes/validate.zarr/traffic_light_faces/992
#   inflating: scenes/validate.zarr/traffic_light_faces/993
#   inflating: scenes/validate.zarr/traffic_light_faces/994
#   inflating: scenes/validate.zarr/traffic_light_faces/995
#   inflating: scenes/validate.zarr/traffic_light_faces/996
#   inflating: scenes/validate.zarr/traffic_light_faces/997
#   inflating: scenes/validate.zarr/traffic_light_faces/998
#   inflating: scenes/validate.zarr/traffic_light_faces/999
#   inflating: semantic_map/LICENSE
#   inflating: semantic_map/feedback.txt
#   inflating: semantic_map/semantic_map.pb
#   inflating: single_mode_sample_submission.csv
